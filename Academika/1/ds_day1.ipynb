# %% [markdown]
# # Инструменты Data Science: анализ зарплат в IT
#
# ## День 1. Тысяча и одна вакансия Data Science. Как разобраться в больших данных

# %% [markdown]
# Ваша корзина в маркетплейсе, список вакансий на сайтах по поиску работы, каталог книг в библиотеке – все это базы данных. Чаще всего мы их представляем в виде таблицы. Это удобно, привычно и хорошо работает.
#
# Наверняка вы уже работали в Excel или Google Таблицах, и представляете, как выглядят столбцы, строки, листы. Основная проблема подобных программ – это ограниченность памяти. Один из самых громких случаев, связанный с таблицами, был в Великобритании, когда правительственное медицинское агентство [потеряло более 16 тысяч результатов тестирования](https://www.kommersant.ru/doc/4520501) на ковид. На листе Excel просто закончилось место.
#
# Мы с вами будем работать с файлами .csv и обрабатывать их с помощью библиотеки pandas. В качестве среды разработки будем использовать Jupyter Notebook. Разберемся, что это:
# * csv-файл – это обычный текстовый файл, в котором данные записываются через запятую (или другой разделитель), благодаря чему их можно быстро перевести в табличную структуру.
# * pandas – это библиотека Python с огромным количеством функций для удобной работы с таблицами.
# * Jupyter Notebook – это программа для интерактивного запуска кода в браузере. Можно писать текст (как этот конспект), код (ячейка ниже) и сразу же смотреть на результаты. Золотой стандарт в Data Science. Файлы Jupyter Notebook с расширением .ipynb (ipython notebook) часто называют "тетрадками".

# %%
import pandas as pd

# %% [markdown]
# Мы импортировали библиотеку pandas под псевдонимом pd (сокращенное имя). Теперь в пределах этой тетрадки мы будем обращаться к библиотеке по имени и вызывать оттуда функции.

# %% [markdown]
# ### Загрузка таблицы из файла

# %%
df = pd.read_csv('DataScienceJobs.csv')

# %% [markdown]
# `df` – это название переменной, в которой будет храниться наша таблица. \
# `pd.read_csv()` – это вызов функции, которая умеет считывать файлы csv и преобразовывать их в объект DataFrame (мы часто будем называть наши таблицы датафреймами). \
# `'DataScienceJobs.csv'` – это название нашего файла, с которым будем работать. Важно, чтобы он лежал в той же папке, что и эта тетрадка .ipynb.
#
# Посмотрим на датафрейм:

# %%
df
# Out:
#                                                   name          address  \
# 0         Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 1                                 Junior Data Engineer  Нижний Новгород
# 2                                           ML-инженер           Москва
# 3                                       Data Scientist           Москва
# 4                            Python Developer (Junior)            Томск
# ..                                                 ...              ...
# 355  Ведущий специалист по разработке скоринговых карт      Новосибирск
# 356       Lead data scientist (Анализ цены и Trade in)           Москва
# 357                              Senior Data Scientist            Томск
# 358                            Data engineer (middle+)      Новосибирск
# 359  Автор дисциплины "Задачи NLP в машинном обучении"  Нижний Новгород
#
#              experience                                             skills  \
# 0    От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 1    От 1 года до 3 лет                                   SQL, jvm, Hadoop
# 2             Нет опыта  Знания математики, алгоритмов, структур данных...
# 3    От 1 года до 3 лет  Python, Machine Learning, Математическое модел...
# 4    От 1 года до 3 лет                            Python, Git, ООП, MySQL
# ..                  ...                                                ...
# 355  От 1 года до 3 лет  SQL, Sas, Базы данных, Скоринговая карта, База...
# 356       От 3 до 6 лет  PyData: Pandas, NumPy, SciPy, scikit-learn, py...
# 357         Более 6 лет  SQL, Анализ данных, A/B тесты, LTV prediction,...
# 358       От 3 до 6 лет  Linux, ETL, Apache Kafka, Apache Spark, Apache...
# 359       От 3 до 6 лет  NLP, ML, Data Science, Обучение и развитие, На...
#
#      sal_from  sal_to
# 0       55000   60000
# 1      150000  200000
# 2      150000  170000
# 3      180000  200000
# 4       60000  110000
# ..        ...     ...
# 355     55000  105000
# 356    180000  200000
# 357    200000  210000
# 358    150000  180000
# 359    270000  320000
#
# [360 rows x 6 columns]

# %%
df.head() # первые пять строк
# Out:
#                                            name          address  \
# 0  Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 1                          Junior Data Engineer  Нижний Новгород
# 2                                    ML-инженер           Москва
# 3                                Data Scientist           Москва
# 4                     Python Developer (Junior)            Томск
#
#            experience                                             skills  \
# 0  От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 1  От 1 года до 3 лет                                   SQL, jvm, Hadoop
# 2           Нет опыта  Знания математики, алгоритмов, структур данных...
# 3  От 1 года до 3 лет  Python, Machine Learning, Математическое модел...
# 4  От 1 года до 3 лет                            Python, Git, ООП, MySQL
#
#    sal_from  sal_to
# 0     55000   60000
# 1    150000  200000
# 2    150000  170000
# 3    180000  200000
# 4     60000  110000

# %%
df.tail() # последние пять строк
# Out:
#                                                   name          address  \
# 355  Ведущий специалист по разработке скоринговых карт      Новосибирск
# 356       Lead data scientist (Анализ цены и Trade in)           Москва
# 357                              Senior Data Scientist            Томск
# 358                            Data engineer (middle+)      Новосибирск
# 359  Автор дисциплины "Задачи NLP в машинном обучении"  Нижний Новгород
#
#              experience                                             skills  \
# 355  От 1 года до 3 лет  SQL, Sas, Базы данных, Скоринговая карта, База...
# 356       От 3 до 6 лет  PyData: Pandas, NumPy, SciPy, scikit-learn, py...
# 357         Более 6 лет  SQL, Анализ данных, A/B тесты, LTV prediction,...
# 358       От 3 до 6 лет  Linux, ETL, Apache Kafka, Apache Spark, Apache...
# 359       От 3 до 6 лет  NLP, ML, Data Science, Обучение и развитие, На...
#
#      sal_from  sal_to
# 355     55000  105000
# 356    180000  200000
# 357    200000  210000
# 358    150000  180000
# 359    270000  320000

# %%
df.sample(10) # 10 случайных строк из датафрейма
# Out:
#                                                   name             address  \
# 184                     Machine Learning Engineer (CV)              Москва
# 206  Middle \ Senior Data scientist (команды CRM и ...              Москва
# 299                                       Data инженер  Московская область
# 271                   Senior Machine Learning Engineer              Москва
# 359  Автор дисциплины "Задачи NLP в машинном обучении"     Нижний Новгород
# 231                              Senior Data Scientist              Москва
# 139                                        ML engineer              Москва
# 322                                       NLP engineer                Сочи
# 234                      Data Scientist Middle+/Senior     Санкт-Петербург
# 327                Middle MLE/DS c NLP направленностью              Москва
#
#              experience                                             skills  \
# 184       От 3 до 6 лет  Cross-validation, Machine Learning, Python, Do...
# 206  От 1 года до 3 лет                      Python, Hadoop, Spark, ML, DL
# 299       От 3 до 6 лет  Clickhouse, АirFlow, Postgres, Grafana, Promet...
# 271       От 3 до 6 лет                           PySpark, Airflow, Hadoop
# 359       От 3 до 6 лет  NLP, ML, Data Science, Обучение и развитие, На...
# 231       От 3 до 6 лет       Python, SQL, Machine Learning, Анализ данных
# 139       От 3 до 6 лет  Желателен опыт в решении ML-задач из банковско...
# 322       От 3 до 6 лет  Python, PostgreSQL, nlp, MATLAB, Анализ данных...
# 234       От 3 до 6 лет     Pandas, Matplotlib, Numpy, Scipy, Sklearn, SQL
# 327  От 1 года до 3 лет  Уверенное знание Python (3.8+) понимание, как ...
#
#      sal_from  sal_to
# 184     80000  100000
# 206    130000  200000
# 299    270000  370000
# 271    100000  110000
# 359    270000  320000
# 231    150000  180000
# 139    180000  210000
# 322    200000  270000
# 234    130000  160000
# 327    150000  300000

# %% [markdown]
# #### Описание показателей:
#
# * name – название вакансии
# * address – город
# * experience – требуемый опыт
# * skills – требуемые навыки
# * sal_from – нижний порог зарплаты
# * sal_to – верхний порог зарплаты
#
#
# Получим сводную информацию по таблице:

# %%
df.shape # (кол-во строк, кол-во столбцов)
# Out:
# (360, 6)

# %%
df.info() # сводная информация о таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        360 non-null    object
#  1   address     360 non-null    object
#  2   experience  360 non-null    object
#  3   skills      360 non-null    object
#  4   sal_from    360 non-null    int64
#  5   sal_to      360 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 17.0+ KB

# %% [markdown]
# Как прочитать таблицу выше?
# 1. `<class 'pandas.core.frame.DataFrame'>` – Python видит нашу таблицу как объект DataFrame.
# 2. `RangeIndex: 360 entries, 0 to 359` – в таблице 360 строк с индексами от 0 до 359. В Python все считается с 0, а не 1, как мы привыкли.
# 3. `Data columns (total 6 columns):` – в таблице 6 колонок.
# 4. После выводится небольшая таблица с информацией о названии колонки (`Column`), количестве непустых ячеек в колонке (`Non-Null Count`), а также тип данных (`Dtype`).
# 5. `dtypes: int64(2), object(4)` – сводка по количеству столбцов с разными типами данных.
# 6. `memory usage: 17.0+ KB` – сколько памяти занимает таблица.

# %% [markdown]
# ## Типы данных

# %% [markdown]
# Для программирования критично важно знать, с какими типами данных вы работаете.
#
# <table>
# <thead><tr>
# <th style="text-align:left">Как мы их называем</th>
# <th style="text-align:left">Как они называютcя по-английски</th>
# <th style="text-align:left">Как они называются в Python</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left"><strong>"Естественные" типы данных</strong></td>
# </tr>
# <tr>
# <td style="text-align:left">целое число</td>
# <td style="text-align:left">integer</td>
# <td style="text-align:left"><code>int</code></td>
# </tr>
# <tr>
# <td style="text-align:left">вещественное число</td>
# <td style="text-align:left">floating-point number</td>
# <td style="text-align:left"><code>float</code></td>
# </tr>
# <tr>
# <td style="text-align:left">логическая переменная</td>
# <td style="text-align:left">boolean / logical</td>
# <td style="text-align:left"><code>bool</code></td>
# </tr>
# <tr>
# <td style="text-align:left"><strong>Упорядоченные типы данных (последовательности)</strong></td>
# </tr>
# <tr>
# <td style="text-align:left">строка</td>
# <td style="text-align:left">string</td>
# <td style="text-align:left"><code>str</code></td>
# </tr>
# <tr>
# <td style="text-align:left">список</td>
# <td style="text-align:left">list</td>
# <td style="text-align:left"><code>list</code></td>
# </tr>
# <tr>
# <td style="text-align:left">кортеж</td>
# <td style="text-align:left">tuple</td>
# <td style="text-align:left"><code>tuple</code></td>
# </tr>
# <tr>
# <td style="text-align:left"><strong>Неупорядоченные типы данных (коллекции)</strong></td>
# </tr>
# <tr>
# <td style="text-align:left">множество</td>
# <td style="text-align:left">set</td>
# <td style="text-align:left"><code>set</code></td>
# </tr>
# <tr>
# <td style="text-align:left">словарь</td>
# <td style="text-align:left">dictionary</td>
# <td style="text-align:left"><code>dict</code></td>
# </tr>
# </tbody>
# </table>
# <table>
# <thead><tr>
# <th>Неизменяемые типы данных</th>
# <th>Изменяемые типы данных</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>кортеж</td>
# <td>список</td>
# </tr>
# <tr>
# <td>строки</td>
# <td>множество</td>
# </tr>
# <tr>
# <td>числа целые и вещественные</td>
# <td>словарь</td>
# </tr>
# <tr>
# <td>логические переменные</td>
# </tr>
# </tbody>
# </table>
# <table>
# <thead><tr>
# <th>Тип данных</th>
# <th>Тип структуры данных</th>
# <th>Как обращаемся к элементу внутри?</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>кортежи</td>
# <td>упорядоченный</td>
# <td>по индексу</td>
# </tr>
# <tr>
# <td>списки</td>
# <td>упорядоченный</td>
# <td>по индексу</td>
# </tr>
# <tr>
# <td>строки</td>
# <td>упорядоченный</td>
# <td>по индексу</td>
# </tr>
# <tr>
# <td>множество</td>
# <td>неупорядоченный</td>
# <td>не можем обратиться к элементу</td>
# </tr>
# <tr>
# <td>Словари</td>
# <td>неупорядоченный</td>
# <td>по ключу</td>
# </tr>
# </tbody>
# </table>

# %%
# целое число (int)

a = 1
print(a)
print(type(a))
# Out:
# 1
# <class 'int'>

# %%
# строка (str)

b = 'hello, world'
print(b)
print(type(b))
# Out:
# hello, world
# <class 'str'>

# %%
# вещественное число (float)

c = 1.5
print(c)
print(type(c))
# Out:
# 1.5
# <class 'float'>

# %%
# логическая константа (bool)

d = True
print(d)
print(type(d))
# Out:
# True
# <class 'bool'>

# %%
# список (list)

e = [1, 1, 'hello, world', 1.5, True]
print(e)
print(type(e))
# Out:
# [1, 1, 'hello, world', 1.5, True]
# <class 'list'>

# %%
# кортеж (tuple)

f = (1, 1, 'hello, world', 1.5, True)
print(f)
print(type(f))
# Out:
# (1, 1, 'hello, world', 1.5, True)
# <class 'tuple'>

# %%
# множество (set)

g = {1, 1, 'hello, world', 1.5, True}
print(g)
print(type(g))
# Out:
# {1, 'hello, world', 1.5}
# <class 'set'>

# %%
# словарь (dict)

h = {1: 1, 'hello': 'world', 1.5: True}
print(h)
print(type(h))
# Out:
# {1: 1, 'hello': 'world', 1.5: True}
# <class 'dict'>

# %% [markdown]
# В нашей таблице встречаются типы данных `object` (строка) и `int64` (целое число).

# %% [markdown]
# ## Обращение к данным в таблице

# %% [markdown]
# ### Обращение к столбцам
#
# `датафрейм['столбец']` или `датафрейм.столбец` – обращение к одному столбцу
#
# `датафрейм[['столбец 1', 'столбец 2', ...]]` – обращение к нескольким столбцам

# %%
df['name'] # данные столбца с названиями вакансий
# Out:
# 0           Начинающий специалист по работе с нейросетям
# 1                                   Junior Data Engineer
# 2                                             ML-инженер
# 3                                         Data Scientist
# 4                              Python Developer (Junior)
#                              ...
# 355    Ведущий специалист по разработке скоринговых карт
# 356         Lead data scientist (Анализ цены и Trade in)
# 357                                Senior Data Scientist
# 358                              Data engineer (middle+)
# 359    Автор дисциплины "Задачи NLP в машинном обучении"
# Name: name, Length: 360, dtype: object

# %%
df.name # данные столбца с названиями вакансий, второй вариант
# Out:
# 0           Начинающий специалист по работе с нейросетям
# 1                                   Junior Data Engineer
# 2                                             ML-инженер
# 3                                         Data Scientist
# 4                              Python Developer (Junior)
#                              ...
# 355    Ведущий специалист по разработке скоринговых карт
# 356         Lead data scientist (Анализ цены и Trade in)
# 357                                Senior Data Scientist
# 358                              Data engineer (middle+)
# 359    Автор дисциплины "Задачи NLP в машинном обучении"
# Name: name, Length: 360, dtype: object

# %%
df[['name', 'experience']] # мини-таблица с названиями вакансий и требуемым опытом работы
# Out:
#                                                   name          experience
# 0         Начинающий специалист по работе с нейросетям  От 1 года до 3 лет
# 1                                 Junior Data Engineer  От 1 года до 3 лет
# 2                                           ML-инженер           Нет опыта
# 3                                       Data Scientist  От 1 года до 3 лет
# 4                            Python Developer (Junior)  От 1 года до 3 лет
# ..                                                 ...                 ...
# 355  Ведущий специалист по разработке скоринговых карт  От 1 года до 3 лет
# 356       Lead data scientist (Анализ цены и Trade in)       От 3 до 6 лет
# 357                              Senior Data Scientist         Более 6 лет
# 358                            Data engineer (middle+)       От 3 до 6 лет
# 359  Автор дисциплины "Задачи NLP в машинном обучении"       От 3 до 6 лет
#
# [360 rows x 2 columns]

# %% [markdown]
# ### Обращение к строкам
#
# `датафрейм.loc['название строки' или индекс]` – обращение к строке по названию \
# `датафрейм.iloc[индекс]` – обращение к строке по индексу (считается с 0)

# %%
df.loc[0] # нулевая по индексу вакансия (самая первая в таблице)
# Out:
# name               Начинающий специалист по работе с нейросетям
# address                                         Санкт-Петербург
# experience                                   От 1 года до 3 лет
# skills        Разработка технических заданий, Python, Сбор и...
# sal_from                                                  55000
# sal_to                                                    60000
# Name: 0, dtype: object

# %%
df.iloc[10] # десятая по индексу вакансия (одиннадцатая по счету в таблице)
# Out:
# name                                    Computer vision инженер
# address                                                  Москва
# experience                                        От 3 до 6 лет
# skills        Опыт в компьютерном зрении от 3 лет, Уверенные...
# sal_from                                                 200000
# sal_to                                                   300000
# Name: 10, dtype: object

# %% [markdown]
# ### Обращение к ячейкам
#
# `датафрейм['столбец'][индекс строки]` или `датафрейм.loc[индекс]['столбец']`

# %%
df['name'][0] # название вакансии в первой строке
# Out:
# 'Начинающий специалист по работе с нейросетям'

# %%
df.loc[0]['name'] # название вакансии в первой строке, второй вариант
# Out:
# 'Начинающий специалист по работе с нейросетям'

# %%
type(df['name'][0]) # тип данных – строка
# Out:
# str

# %%
df['sal_from'][0] # нижняя граница зарплаты в первой вакансии
# Out:
# 55000

# %%
type(df['sal_from'][0]) # тип данных – целое число; 
                        # numpy – это название библиотеки, которая лежит под капотом pandas 
                        # для математических вычислений
# Out:
# numpy.int64

# %% [markdown]
# ## Фильтрация данных

# %% [markdown]
# ### Фильтрация по столбцу
#
# `датафрейм[датафрейм['столбец'] <оператор сравнения> условие]`
#
# |Оператор|Значение|
# |:---:|:---:|
# |==|равно|
# |!=|не равно|
# |>|больше чем|
# |<|меньше чем|
# |>=|больше или равно чем|
# |<=|меньше или равно чем|

# %%
df[df['address'] == 'Москва'] # только вакансии в Москве
# Out:
#                                                   name address  \
# 2                                           ML-инженер  Москва
# 3                                       Data Scientist  Москва
# 5                                 Data Scientist (NLP)  Москва
# 6    Специалист по работе с нейронными сетями\Promt...  Москва
# 7         Junior / Middle ML Engineer (Data Scientist)  Москва
# ..                                                 ...     ...
# 349              Руководитель направления Data Science  Москва
# 351                        Data Scientist Teamlead NLP  Москва
# 352  Medical foundation model research data scienti...  Москва
# 354       Senior Data Scientist CV (Generative design)  Москва
# 356       Lead data scientist (Анализ цены и Trade in)  Москва
#
#              experience                                             skills  \
# 2             Нет опыта  Знания математики, алгоритмов, структур данных...
# 3    От 1 года до 3 лет  Python, Machine Learning, Математическое модел...
# 5         От 3 до 6 лет  Python, NLP, Artificial intelligence, Искусств...
# 6    От 1 года до 3 лет  Большой интерес к инновациям в области медиа и...
# 7    От 1 года до 3 лет  Python, Pandas, NumPy, Transformers, openai, L...
# ..                  ...                                                ...
# 349       От 3 до 6 лет                                        Python, SQL
# 351       От 3 до 6 лет     SQL, Python, PyTorch, Docker, Hadoop, DVC, git
# 352       От 3 до 6 лет                                            PyTorch
# 354       От 3 до 6 лет  Machine Learning, ML, Data Science, DS, Машинн...
# 356       От 3 до 6 лет  PyData: Pandas, NumPy, SciPy, scikit-learn, py...
#
#      sal_from  sal_to
# 2      150000  170000
# 3      180000  200000
# 5      200000  400000
# 6      280000  330000
# 7      170000  180000
# ..        ...     ...
# 349    280000  350000
# 351    200000  270000
# 352    180000  250000
# 354    100000  150000
# 356    180000  200000
#
# [188 rows x 6 columns]

# %%
df[df['sal_from'] >= 200000] # только вакансии с зарплатой не менее 200000 рублей
# Out:
#                                                   name             address  \
# 5                                 Data Scientist (NLP)              Москва
# 6    Специалист по работе с нейронными сетями\Promt...              Москва
# 8                                          ML engineer              Москва
# 9                     Senior Machine Learning Engineer              Москва
# 10                             Computer vision инженер              Москва
# ..                                                 ...                 ...
# 348                        Senior Data Scientist (NLP)  Московская область
# 349              Руководитель направления Data Science              Москва
# 351                        Data Scientist Teamlead NLP              Москва
# 357                              Senior Data Scientist               Томск
# 359  Автор дисциплины "Задачи NLP в машинном обучении"     Нижний Новгород
#
#              experience                                             skills  \
# 5         От 3 до 6 лет  Python, NLP, Artificial intelligence, Искусств...
# 6    От 1 года до 3 лет  Большой интерес к инновациям в области медиа и...
# 8    От 1 года до 3 лет  Уверенное владение Python;   Уверенное владени...
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
# 10        От 3 до 6 лет  Опыт в компьютерном зрении от 3 лет, Уверенные...
# ..                  ...                                                ...
# 348       От 3 до 6 лет  Python, PyTorch, Clickhouse, Docker, K8S, hugg...
# 349       От 3 до 6 лет                                        Python, SQL
# 351       От 3 до 6 лет     SQL, Python, PyTorch, Docker, Hadoop, DVC, git
# 357         Более 6 лет  SQL, Анализ данных, A/B тесты, LTV prediction,...
# 359       От 3 до 6 лет  NLP, ML, Data Science, Обучение и развитие, На...
#
#      sal_from  sal_to
# 5      200000  400000
# 6      280000  330000
# 8      200000  250000
# 9      350000  570000
# 10     200000  300000
# ..        ...     ...
# 348    270000  320000
# 349    280000  350000
# 351    200000  270000
# 357    200000  210000
# 359    270000  320000
#
# [147 rows x 6 columns]

# %% [markdown]
# ### Фильтрация по нескольким условиям
#
# `&` - и \
# `|` - или
#
# Все условия должны быть в скобках!

# %%
df[(df['address'] == 'Москва') | (df['address'] == 'Казань')] # вакансии в Москве или Казани
# Out:
#                                                   name address  \
# 2                                           ML-инженер  Москва
# 3                                       Data Scientist  Москва
# 5                                 Data Scientist (NLP)  Москва
# 6    Специалист по работе с нейронными сетями\Promt...  Москва
# 7         Junior / Middle ML Engineer (Data Scientist)  Москва
# ..                                                 ...     ...
# 349              Руководитель направления Data Science  Москва
# 351                        Data Scientist Teamlead NLP  Москва
# 352  Medical foundation model research data scienti...  Москва
# 354       Senior Data Scientist CV (Generative design)  Москва
# 356       Lead data scientist (Анализ цены и Trade in)  Москва
#
#              experience                                             skills  \
# 2             Нет опыта  Знания математики, алгоритмов, структур данных...
# 3    От 1 года до 3 лет  Python, Machine Learning, Математическое модел...
# 5         От 3 до 6 лет  Python, NLP, Artificial intelligence, Искусств...
# 6    От 1 года до 3 лет  Большой интерес к инновациям в области медиа и...
# 7    От 1 года до 3 лет  Python, Pandas, NumPy, Transformers, openai, L...
# ..                  ...                                                ...
# 349       От 3 до 6 лет                                        Python, SQL
# 351       От 3 до 6 лет     SQL, Python, PyTorch, Docker, Hadoop, DVC, git
# 352       От 3 до 6 лет                                            PyTorch
# 354       От 3 до 6 лет  Machine Learning, ML, Data Science, DS, Машинн...
# 356       От 3 до 6 лет  PyData: Pandas, NumPy, SciPy, scikit-learn, py...
#
#      sal_from  sal_to
# 2      150000  170000
# 3      180000  200000
# 5      200000  400000
# 6      280000  330000
# 7      170000  180000
# ..        ...     ...
# 349    280000  350000
# 351    200000  270000
# 352    180000  250000
# 354    100000  150000
# 356    180000  200000
#
# [203 rows x 6 columns]

# %%
# вакансии в Казани с уровнем опыта от 3 до 6 лет

df[(df['address'] == 'Казань') & (df['experience'] == 'От 3 до 6 лет')]
# Out:
#                                            name address     experience  \
# 55                               Data Scientist  Казань  От 3 до 6 лет
# 119                              Data Scientist  Казань  От 3 до 6 лет
# 289                       Senior NLP Researcher  Казань  От 3 до 6 лет
# 297  Deep Learning Engineer (Motion Prediction)  Казань  От 3 до 6 лет
# 302           Team Lead Data Scientist (RecSys)  Казань  От 3 до 6 лет
#
#                                                 skills  sal_from  sal_to
# 55                                              Python     55000   85000
# 119  Опыт Python разработчика (pytorch, opencv), зн...    300000  330000
# 289  PyTorch, TensorFlow, Transformers, T5, Bert, H...     55000  125000
# 297  C++, Python, Cuda, Computer vision, Deep Learning    120000  170000
# 302             Machine learning, Data science, RecSys    270000  300000

# %%
# вакансии в Москве или Казани с требуемым опытом от 3 до 6 лет и зарплатой не менее 200000 рублей

df[((df['address'] == 'Москва') | (df['address'] == 'Казань')) 
    & (df['experience'] == 'От 3 до 6 лет') 
    & (df['sal_from'] >= 200000)]
# Out:
#                                                   name address     experience  \
# 5                                 Data Scientist (NLP)  Москва  От 3 до 6 лет
# 9                     Senior Machine Learning Engineer  Москва  От 3 до 6 лет
# 10                             Computer vision инженер  Москва  От 3 до 6 лет
# 11                                      Data Scientist  Москва  От 3 до 6 лет
# 16                                       ML специалист  Москва  От 3 до 6 лет
# 25                           Machine learning engineer  Москва  От 3 до 6 лет
# 58                                Аналитик-разработчик  Москва  От 3 до 6 лет
# 71                        Data Scientist middle/senior  Москва  От 3 до 6 лет
# 86                                     Аналитик данных  Москва  От 3 до 6 лет
# 108                                Senior Data Science  Москва  От 3 до 6 лет
# 111                   Дата-инженер (Motion Prediction)  Москва  От 3 до 6 лет
# 119                                     Data Scientist  Казань  От 3 до 6 лет
# 128                  Data Scientist в команду аукциона  Москва  От 3 до 6 лет
# 129                                  Архитектор данных  Москва  От 3 до 6 лет
# 133                                     Data Scientist  Москва  От 3 до 6 лет
# 152                          Machine Learning Engineer  Москва  От 3 до 6 лет
# 157                             Team-Lead Data Science  Москва  От 3 до 6 лет
# 167                                     Data Scientist  Москва  От 3 до 6 лет
# 196                Data Scientist, Ранжирование поиска  Москва  От 3 до 6 лет
# 207                           ML&Optimization engineer  Москва  От 3 до 6 лет
# 210                         Data Engineer (Perception)  Москва  От 3 до 6 лет
# 212                Data scientist TTS (Text To Speech)  Москва  От 3 до 6 лет
# 237                                    Разработчик ETL  Москва  От 3 до 6 лет
# 240        Machine Learning / Computer Vision Engineer  Москва  От 3 до 6 лет
# 244                         Senior/Lead Data Scientist  Москва  От 3 до 6 лет
# 254                                 Lead Data Engineer  Москва  От 3 до 6 лет
# 255                                     Data Scientist  Москва  От 3 до 6 лет
# 256                              Teamlead Data Science  Москва  От 3 до 6 лет
# 257                              Senior Data scientist  Москва  От 3 до 6 лет
# 263                             Data Scienti​​​​​​​st   Москва  От 3 до 6 лет
# 265                           Data Scientist (Scoring)  Москва  От 3 до 6 лет
# 270                 ML Data Scientist (Middle, Senior)  Москва  От 3 до 6 лет
# 274                                     Data scientist  Москва  От 3 до 6 лет
# 277  Senior Data инженер в команду Data Финансовой ...  Москва  От 3 до 6 лет
# 280                                 Lead Data Engineer  Москва  От 3 до 6 лет
# 281                                        ML Engineer  Москва  От 3 до 6 лет
# 287               Computer Vision engineer (Team lead)  Москва  От 3 до 6 лет
# 294                                     Data Scientist  Москва  От 3 до 6 лет
# 302                  Team Lead Data Scientist (RecSys)  Казань  От 3 до 6 лет
# 303             Руководитель группы машинного обучения  Москва  От 3 до 6 лет
# 307                                     Data Scientist  Москва  От 3 до 6 лет
# 320               Senior MLE/DS в команду рекомендаций  Москва  От 3 до 6 лет
# 323                    Middle NLP Data Scientist (LLM)  Москва  От 3 до 6 лет
# 328                                Senior NLP Engineer  Москва  От 3 до 6 лет
# 332                                       NLP engineer  Москва  От 3 до 6 лет
# 338                    Middle NLP Data Scientist (LLM)  Москва  От 3 до 6 лет
# 342                     Machine Learning Lead engineer  Москва  От 3 до 6 лет
# 349              Руководитель направления Data Science  Москва  От 3 до 6 лет
# 351                        Data Scientist Teamlead NLP  Москва  От 3 до 6 лет
#
#                                                 skills  sal_from  sal_to
# 5    Python, NLP, Artificial intelligence, Искусств...    200000  400000
# 9    Machine Learning, Python, numpy, pandas, matpl...    350000  570000
# 10   Опыт в компьютерном зрении от 3 лет, Уверенные...    200000  300000
# 11   Python, SQL, Обучение и развитие, Машинное обу...    270000  300000
# 16   Pytorch, TensorFlow, OpenVino, OpenCV, Pandas,...    200000  200000
# 25                 Хорошие навыки разработки на Python    270000  350000
# 58                                 Python, LLM, Speech    270000  300000
# 71          Python, Hadoop, Big Data, Machine Learning    210000  260000
# 86   Python, SQL, Математическая статистика, Big Da...    270000  320000
# 108  Уметь выкладывать свой код в кластер кубернете...    200000  300000
# 111      Python, Spark, Dagster, S3, Kafka, Kubernetes    280000  310000
# 119  Опыт Python разработчика (pytorch, opencv), зн...    300000  330000
# 128  Python, Big Data, Математическая статистика, М...    210000  310000
# 129  Базы данных, Моделирование бизнес процессов, М...    280000  330000
# 133  Уверенное владение Python. Опыт работы с библи...    280000  330000
# 152                    Python, Machine Learning, Linux    200000  220000
# 157                Python, Docker, Kubernetes, RESTAPI    300000  350000
# 167          pandas, TensorFlow, PyTorch, Scikit-learn    210000  280000
# 196  Python, data science, Разработка поисковых тех...    270000  290000
# 207                                   ML и DL (Python)    300000  350000
# 210      Python, Spark, Dagster, S3, Kafka, Kubernetes    280000  290000
# 212  TTS, Text to speach, NumPy, Matplotlib, pandas...    200000  300000
# 237  SAP BusinessObject, SAP DataIntegrator, MS SQL...    200000  230000
# 240  Python, PyTorch, Machine Learning, Deep Learni...    210000  260000
# 244  Python, classic ML, Data Science, SQL, Airflow...    270000  300000
# 254   Greenplum (Arenadata DB), PostgreSQL, Clickhouse    300000  320000
# 255  Python, SQL, MS SQL, ORACLE, PostgreSQL, Git, ...    200000  250000
# 256  Python, Big Data, Kubernetes, FastAPI, Pytorch...    280000  290000
# 257      Python ML stack, Python NLP stack, JupyterLab    270000  370000
# 263  Python, jupyter, pycharm, sql, pyspark, sparkM...    210000  260000
# 265  Опыт построения моделей с помощью классическог...    300000  310000
# 270       Python, Machine Learning, Bokeh, Plotly, SQL    270000  320000
# 274                                            SQL, ML    270000  340000
# 277                                      Python, Scala    280000  300000
# 280                             Python, PL/pgSQL и SQL    200000  210000
# 281  Python, Docker, SCALA, Hadoop, Big Data, Spark...    300000  350000
# 287    Python, Linux, OpenCV, PyTorch, Computer Vision    280000  330000
# 294        Scikit-learn, TensorFlow, XGBoost, CatBoost    300000  370000
# 302             Machine learning, Data science, RecSys    270000  300000
# 303                        Python, Управление командой    300000  370000
# 307                                        Python, SQL    210000  310000
# 320                              ML (GBDT, LR), Kotlin    300000  500000
# 323  Аналитическое мышление, Аналитические исследов...    200000  210000
# 328  Transformers, GPT, LLMs, BERT, T5, чат-боты, f...    270000  340000
# 332  Python, PostgreSQL, nlp, MATLAB, Анализ данных...    210000  260000
# 338  Аналитическое мышление, Аналитические исследов...    280000  310000
# 342                           Machine Learning, ML, C#    270000  280000
# 349                                        Python, SQL    280000  350000
# 351     SQL, Python, PyTorch, Docker, Hadoop, DVC, git    200000  270000

# %% [markdown]
# ### Подсчет строк после фильтрации

# %%
df[((df['address'] == 'Москва') | (df['address'] == 'Казань')) 
    & (df['experience'] == 'От 3 до 6 лет') 
    & (df['sal_from'] >= 200000)].shape
# Out:
# (49, 6)

# %% [markdown]
# В нашей таблице есть 49 вакансий в Москве или Казани с требуемым опытом от 3 до 6 лет и зарплатой не менее 200000 рублей.

# %% [markdown]
# ## Сортировка данных
#
# ### По одному условию
#
# `датафрейм.sort_values('столбец')` – сортировка по одному столбцу (от наименьшего к наибольшему)
# `датафрейм.sort_values('столбец', ascending=False)` – сортировка по одному столбцу (от наибольшего к наименьшему)

# %%
df.sort_values('sal_from')
# Out:
#                                                   name          address  \
# 275     Специалист в группу технического сопровождения      Новосибирск
# 0         Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 289                              Senior NLP Researcher           Казань
# 217  Data Scientist (Deep Learning for Demand Forec...  Санкт-Петербург
# 55                                      Data Scientist           Казань
# ..                                                 ...              ...
# 119                                     Data Scientist           Казань
# 118                            Data Scientist (middle)             Сочи
# 192                              Senior Data Scientist           Москва
# 204                              Senior Data Scientist     Екатеринбург
# 9                     Senior Machine Learning Engineer           Москва
#
#              experience                                             skills  \
# 275  От 1 года до 3 лет  MS SQL, PostgreSQL, API, Базы данных, Техничес...
# 0    От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 289       От 3 до 6 лет  PyTorch, TensorFlow, Transformers, T5, Bert, H...
# 217       От 3 до 6 лет        Deep Learning, Прогнозирование, Time Series
# 55        От 3 до 6 лет                                             Python
# ..                  ...                                                ...
# 119       От 3 до 6 лет  Опыт Python разработчика (pytorch, opencv), зн...
# 118  От 1 года до 3 лет                                   Python, SQL, API
# 192  От 1 года до 3 лет  SQL, MS SQL, Big Data, Python, Spark, Hadoop, ...
# 204       От 3 до 6 лет  Python, SQL, Spark, Базы данных, PHP, ClickHou...
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
#
#      sal_from  sal_to
# 275     45000  145000
# 0       55000   60000
# 289     55000  125000
# 217     55000  105000
# 55      55000   85000
# ..        ...     ...
# 119    300000  330000
# 118    300000  370000
# 192    300000  350000
# 204    330000  450000
# 9      350000  570000
#
# [360 rows x 6 columns]

# %%
df.sort_values('sal_from', ascending=False)
# Out:
#                                                   name             address  \
# 9                     Senior Machine Learning Engineer              Москва
# 204                              Senior Data Scientist        Екатеринбург
# 49                                 ML разработчик, B2B  Московская область
# 119                                     Data Scientist              Казань
# 305              Стажер - разработчик скоринговых карт     Санкт-Петербург
# ..                                                 ...                 ...
# 60                                      Data Scientist              Тюмень
# 186                                      Data Engineer         Новосибирск
# 217  Data Scientist (Deep Learning for Demand Forec...     Санкт-Петербург
# 0         Начинающий специалист по работе с нейросетям     Санкт-Петербург
# 275     Специалист в группу технического сопровождения         Новосибирск
#
#              experience                                             skills  \
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
# 204       От 3 до 6 лет  Python, SQL, Spark, Базы данных, PHP, ClickHou...
# 49        От 3 до 6 лет                       Python, Pyspark, Финансы, IT
# 119       От 3 до 6 лет  Опыт Python разработчика (pytorch, opencv), зн...
# 305           Нет опыта  SQL, Python, Базы данных, Скоринговая карта, Б...
# ..                  ...                                                ...
# 60   От 1 года до 3 лет               sklearn, scipy, pytorch, Git, Docker
# 186       От 3 до 6 лет  SQL, Python, Airflow, ORACLE, Postgres, Git, C...
# 217       От 3 до 6 лет        Deep Learning, Прогнозирование, Time Series
# 0    От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 275  От 1 года до 3 лет  MS SQL, PostgreSQL, API, Базы данных, Техничес...
#
#      sal_from  sal_to
# 9      350000  570000
# 204    330000  450000
# 49     300000  320000
# 119    300000  330000
# 305    300000  370000
# ..        ...     ...
# 60      55000  105000
# 186     55000   65000
# 217     55000  105000
# 0       55000   60000
# 275     45000  145000
#
# [360 rows x 6 columns]

# %% [markdown]
# ### По нескольким условиям
#
# `датафрейм.sort_values(['столбец1', 'столбец2', ...])` – сортировка по нескольким столбцам от наименьшего к наибольшему \
# `датафрейм.sort_values(['столбец1', 'столбец2', ...], ascending=False)` – сортировка по нескольким столбцам от наибольшего к наименьшему \
# `датафрейм.sort_values(['столбец1', 'столбец2'], ascending=[False, True])` – сортировка сначала по первому столбцу от наибольшего к наименьшему, затем по второму столбцу от наименьшего к наибольшему

# %%
df.sort_values(['sal_from', 'sal_to'])
# Out:
#                                                  name          address  \
# 275    Специалист в группу технического сопровождения      Новосибирск
# 17                                Стажер Data analyst           Москва
# 0        Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 186                                     Data Engineer      Новосибирск
# 55                                     Data Scientist           Казань
# ..                                                ...              ...
# 305             Стажер - разработчик скоринговых карт  Санкт-Петербург
# 333  Senior Data science expert в Центр технологий ИИ      Новосибирск
# 320              Senior MLE/DS в команду рекомендаций           Москва
# 204                             Senior Data Scientist     Екатеринбург
# 9                    Senior Machine Learning Engineer           Москва
#
#              experience                                             skills  \
# 275  От 1 года до 3 лет  MS SQL, PostgreSQL, API, Базы данных, Техничес...
# 17            Нет опыта  Писать SQL-запросы (у нас Greenplum), Анализир...
# 0    От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 186       От 3 до 6 лет  SQL, Python, Airflow, ORACLE, Postgres, Git, C...
# 55        От 3 до 6 лет                                             Python
# ..                  ...                                                ...
# 305           Нет опыта  SQL, Python, Базы данных, Скоринговая карта, Б...
# 333       От 3 до 6 лет  Python, SQL, алгоритмы ML, Pandas, Sklearn, Nu...
# 320       От 3 до 6 лет                              ML (GBDT, LR), Kotlin
# 204       От 3 до 6 лет  Python, SQL, Spark, Базы данных, PHP, ClickHou...
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
#
#      sal_from  sal_to
# 275     45000  145000
# 17      55000   55000
# 0       55000   60000
# 186     55000   65000
# 55      55000   85000
# ..        ...     ...
# 305    300000  370000
# 333    300000  400000
# 320    300000  500000
# 204    330000  450000
# 9      350000  570000
#
# [360 rows x 6 columns]

# %%
df.sort_values(['sal_from', 'sal_to'], ascending=False)
# Out:
#                                                  name          address  \
# 9                    Senior Machine Learning Engineer           Москва
# 204                             Senior Data Scientist     Екатеринбург
# 320              Senior MLE/DS в команду рекомендаций           Москва
# 333  Senior Data science expert в Центр технологий ИИ      Новосибирск
# 79                                     Data Scientist            Томск
# ..                                                ...              ...
# 55                                     Data Scientist           Казань
# 186                                     Data Engineer      Новосибирск
# 0        Начинающий специалист по работе с нейросетям  Санкт-Петербург
# 17                                Стажер Data analyst           Москва
# 275    Специалист в группу технического сопровождения      Новосибирск
#
#              experience                                             skills  \
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
# 204       От 3 до 6 лет  Python, SQL, Spark, Базы данных, PHP, ClickHou...
# 320       От 3 до 6 лет                              ML (GBDT, LR), Kotlin
# 333       От 3 до 6 лет  Python, SQL, алгоритмы ML, Pandas, Sklearn, Nu...
# 79        От 3 до 6 лет  Spark, Hive, MLFlow, ML, AirFlow, MLOps, Forec...
# ..                  ...                                                ...
# 55        От 3 до 6 лет                                             Python
# 186       От 3 до 6 лет  SQL, Python, Airflow, ORACLE, Postgres, Git, C...
# 0    От 1 года до 3 лет  Разработка технических заданий, Python, Сбор и...
# 17            Нет опыта  Писать SQL-запросы (у нас Greenplum), Анализир...
# 275  От 1 года до 3 лет  MS SQL, PostgreSQL, API, Базы данных, Техничес...
#
#      sal_from  sal_to
# 9      350000  570000
# 204    330000  450000
# 320    300000  500000
# 333    300000  400000
# 79     300000  370000
# ..        ...     ...
# 55      55000   85000
# 186     55000   65000
# 0       55000   60000
# 17      55000   55000
# 275     45000  145000
#
# [360 rows x 6 columns]

# %%
df.sort_values(['sal_from', 'sal_to'], ascending=[False, True])
# Out:
#                                                   name          address  \
# 9                     Senior Machine Learning Engineer           Москва
# 204                              Senior Data Scientist     Екатеринбург
# 42   Эксперт по моделированию и анализу данных / Da...           Москва
# 171                                      Data Engineer           Москва
# 208                    Middle Computer Vision Engineer           Москва
# ..                                                 ...              ...
# 60                                      Data Scientist           Тюмень
# 217  Data Scientist (Deep Learning for Demand Forec...  Санкт-Петербург
# 355  Ведущий специалист по разработке скоринговых карт      Новосибирск
# 289                              Senior NLP Researcher           Казань
# 275     Специалист в группу технического сопровождения      Новосибирск
#
#              experience                                             skills  \
# 9         От 3 до 6 лет  Machine Learning, Python, numpy, pandas, matpl...
# 204       От 3 до 6 лет  Python, SQL, Spark, Базы данных, PHP, ClickHou...
# 42   От 1 года до 3 лет     SQL, Git, Python, Анализ данных, Моделирование
# 171  От 1 года до 3 лет  Scala / Python Hadoop (hdfs, hive) Apache Spar...
# 208  От 1 года до 3 лет  NumPy, Pandas, OpenCV, Sklearn, Matplotlib, CI/CD
# ..                  ...                                                ...
# 60   От 1 года до 3 лет               sklearn, scipy, pytorch, Git, Docker
# 217       От 3 до 6 лет        Deep Learning, Прогнозирование, Time Series
# 355  От 1 года до 3 лет  SQL, Sas, Базы данных, Скоринговая карта, База...
# 289       От 3 до 6 лет  PyTorch, TensorFlow, Transformers, T5, Bert, H...
# 275  От 1 года до 3 лет  MS SQL, PostgreSQL, API, Базы данных, Техничес...
#
#      sal_from  sal_to
# 9      350000  570000
# 204    330000  450000
# 42     300000  310000
# 171    300000  310000
# 208    300000  310000
# ..        ...     ...
# 60      55000  105000
# 217     55000  105000
# 355     55000  105000
# 289     55000  125000
# 275     45000  145000
#
# [360 rows x 6 columns]

# %%
df['name'].value_counts()
# Out:
# name
# Data Scientist                                       36
# Data Engineer                                        18
# Senior Data Scientist                                 8
# Machine Learning Engineer                             6
# ML Engineer                                           6
#                                                      ..
# MLOps/ML Инженер                                      1
# Менеджер по управлению данными                        1
# Data analyst                                          1
# Computer Vision Engineer                              1
# Автор дисциплины "Задачи NLP в машинном обучении"     1
# Name: count, Length: 246, dtype: int64

# %%
df['name'].nunique()
# Out:
# 246

# %%
df[df['name'].str.contains('Data Scientist')
   |df['name'].str.contains('Data scientist')
   |df['name'].str.contains('data scientist')]
# Out:
#                                                   name       address  \
# 3                                       Data Scientist        Москва
# 5                                 Data Scientist (NLP)        Москва
# 7         Junior / Middle ML Engineer (Data Scientist)        Москва
# 11                                      Data Scientist        Москва
# 12                      Data Scientist (Junior/middle)  Екатеринбург
# ..                                                 ...           ...
# 352  Medical foundation model research data scienti...        Москва
# 353  Data Scientist (Автор курса "Векторизация и ра...        Тюмень
# 354       Senior Data Scientist CV (Generative design)        Москва
# 356       Lead data scientist (Анализ цены и Trade in)        Москва
# 357                              Senior Data Scientist         Томск
#
#              experience                                             skills  \
# 3    От 1 года до 3 лет  Python, Machine Learning, Математическое модел...
# 5         От 3 до 6 лет  Python, NLP, Artificial intelligence, Искусств...
# 7    От 1 года до 3 лет  Python, Pandas, NumPy, Transformers, openai, L...
# 11        От 3 до 6 лет  Python, SQL, Обучение и развитие, Машинное обу...
# 12   От 1 года до 3 лет  Python, Математическая статистика, Английский ...
# ..                  ...                                                ...
# 352       От 3 до 6 лет                                            PyTorch
# 353       От 3 до 6 лет         NLP, Python, ML, Математическая статистика
# 354       От 3 до 6 лет  Machine Learning, ML, Data Science, DS, Машинн...
# 356       От 3 до 6 лет  PyData: Pandas, NumPy, SciPy, scikit-learn, py...
# 357         Более 6 лет  SQL, Анализ данных, A/B тесты, LTV prediction,...
#
#      sal_from  sal_to
# 3      180000  200000
# 5      200000  400000
# 7      170000  180000
# 11     270000  300000
# 12     180000  200000
# ..        ...     ...
# 352    180000  250000
# 353    100000  170000
# 354    100000  150000
# 356    180000  200000
# 357    200000  210000
#
# [151 rows x 6 columns]
